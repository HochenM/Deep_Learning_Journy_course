# %%
import tensorflow
import torch

# %%
print(tensorflow.__version__)
print(torch.__version__)
# Out:
# 2.20.0
# 2.9.1+cpu

# %%
import torchvision

# %%
torchvision.__version__
# Out:
# '0.24.1+cpu'

# %%
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import InputLayer, Dense, Conv2D, MaxPooling2D, Flatten, Dropout
# from tensorflow.keras.metrics import MSE
# from tensorflow.keras.losses import binary_crossentropy
#
# from tensorflow.keras.utils import plot_model, to_categorical, image_dataset_from_directory
# from tensorflow.keras.preprocessing.sequence import `
# from tensorflow.keras.regularizers import l1_l2,
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping, TensorBoard, Callback

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer, Dense

# %%
from tensorflow.keras.backend import backend
print(backend())
# Out:
# tensorflow

# %%
# 1000*5 -> classification (3 class)


model = Sequential([
    InputLayer(shape=(5,)),

    Dense(5),
    Dense(5),
    Dense(5),

    Dense(3)
])

# %%
model.summary()
# Out:
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_4 (LSTM)                   │ (None, 1)              │            88 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_15 (Dense)                │ (None, 3)              │             6 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 94 (376.00 B)
#  Trainable params: 94 (376.00 B)
#  Non-trainable params: 0 (0.00 B)
