# %%
from tensorflow.keras.datasets import mnist

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train.shape, x_test.shape
# Out:
# ((60000, 784), (10000, 784))

# %%
# Out:
# [7 2 1 ... 4 5 6]

# %%
from sklearn.neural_network import MLPClassifier

model = MLPClassifier(
    hidden_layer_sizes=(32,32),
    activation="relu",
    solver="adam",
    max_iter=100,
    learning_rate_init=0.001,
    verbose=True,
    tol=0.0001,
    early_stopping=True,
)
model.fit(x_train, y_train)
# Out:
# Iteration 1, loss = 3.18282304
# Iteration 2, loss = 0.74574982
# Iteration 3, loss = 0.51040761
# Iteration 4, loss = 0.40992772
# Iteration 5, loss = 0.34696809
# Iteration 6, loss = 0.30215218
# Iteration 7, loss = 0.27075172
# Iteration 8, loss = 0.25181737
# Iteration 9, loss = 0.23371183
# Iteration 10, loss = 0.22119942
# Iteration 11, loss = 0.20540714
# Iteration 12, loss = 0.19836721
# Iteration 13, loss = 0.19090363
# Iteration 14, loss = 0.18179309
# Iteration 15, loss = 0.17789442
# Iteration 16, loss = 0.17149123
# Iteration 17, loss = 0.16483440
# Iteration 18, loss = 0.15866311
# Iteration 19, loss = 0.15482151
# Iteration 20, loss = 0.15030788
# Iteration 21, loss = 0.14494072
# Iteration 22, loss = 0.14499652
# Iteration 23, loss = 0.13882570
# Iteration 24, loss = 0.13591834
# Iteration 25, loss = 0.13099114
# Iteration 26, loss = 0.12595040
# Iteration 27, loss = 0.12523660
# Iteration 28, loss = 0.12029471
# Iteration 29, loss = 0.11910189
# Iteration 30, loss = 0.11665449
# Iteration 31, loss = 0.10756898
# Iteration 32, loss = 0.11037544
# Iteration 33, loss = 0.10574317
# Iteration 34, loss = 0.10096126
# Iteration 35, loss = 0.10137606
# Iteration 36, loss = 0.09952182
# Iteration 37, loss = 0.09467729
# Iteration 38, loss = 0.09614150
# Iteration 39, loss = 0.09728269
# Iteration 40, loss = 0.09417089
# Iteration 41, loss = 0.08804679
# Iteration 42, loss = 0.08748472
# Iteration 43, loss = 0.08368329
# Iteration 44, loss = 0.08605213
# Iteration 45, loss = 0.08750307
# Iteration 46, loss = 0.08438061
# Iteration 47, loss = 0.07977034
# Iteration 48, loss = 0.07898371
# Iteration 49, loss = 0.07741729
# Iteration 50, loss = 0.08128028
# Iteration 51, loss = 0.07710629
# Iteration 52, loss = 0.07655251
# Iteration 53, loss = 0.07363007
# Iteration 54, loss = 0.07221134
# Iteration 55, loss = 0.07162737
# Iteration 56, loss = 0.07023253
# Iteration 57, loss = 0.07181491
# Iteration 58, loss = 0.06973525
# Iteration 59, loss = 0.06624663
# Iteration 60, loss = 0.06740651
# Iteration 61, loss = 0.06876091
# Iteration 62, loss = 0.06536209
# Iteration 63, loss = 0.06187795
# Iteration 64, loss = 0.06508539
# Iteration 65, loss = 0.05852875
# Iteration 66, loss = 0.06405398
# Iteration 67, loss = 0.06574362
# Iteration 68, loss = 0.06260665
# Iteration 69, loss = 0.05888671
# Iteration 70, loss = 0.06297548
# Iteration 71, loss = 0.06067977
# Iteration 72, loss = 0.05842453
# Iteration 73, loss = 0.05652577
# Iteration 74, loss = 0.05453583
# Iteration 75, loss = 0.05629462
# Iteration 76, loss = 0.05636269
# Iteration 77, loss = 0.05639638
# Iteration 78, loss = 0.05494961
# Iteration 79, loss = 0.04894519
# Iteration 80, loss = 0.05410697
# Iteration 81, loss = 0.05743530
# Iteration 82, loss = 0.05150409
# Iteration 83, loss = 0.05272991
# Iteration 84, loss = 0.05263419
# Iteration 85, loss = 0.04932149
# Iteration 86, loss = 0.04926359
# Iteration 87, loss = 0.04815942
# Iteration 88, loss = 0.05376909
# Iteration 89, loss = 0.04799128
# Iteration 90, loss = 0.04803078
# Iteration 91, loss = 0.04709395
# Iteration 92, loss = 0.04764071
# Iteration 93, loss = 0.04847915
# Iteration 94, loss = 0.04808224
# Iteration 95, loss = 0.04523368
# Iteration 96, loss = 0.04846657
# Iteration 97, loss = 0.04913578
# Iteration 98, loss = 0.04860584
# Iteration 99, loss = 0.04587322
# Iteration 100, loss = 0.04505979
# C:\Program Files\Python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:785: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLPClassifier(hidden_layer_sizes=(32, 32), max_iter=100, verbose=True)

# %%
from tensorflow.keras import models, layers

class MyCustomLayer(layers.Layer):
    def build(self, input_shape):
        pass

def my_function(X):
    pass

model = models.Sequential([
    layers.Input(shape=(28,28)),

    layers.Flatten(),

    layers.Dense(32, activation="relu"),

    # layers.Lambda(my_function),

    layers.Dense(32, activation="relu"),

    layers.Dense(10, activation="softmax")
])



model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 32)             │        25,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ (None, 10)             │           330 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 26,506 (103.54 KB)
#  Trainable params: 26,506 (103.54 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.optimizers import Adam

adam= Adam(learning_rate=0.001)

model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
from tensorflow.keras.callbacks import Callback

class MyCallBack(Callback):
    def on_train_begin(self, logs={}):
        print("Train begin")

    def on_train_end(self, logs=None):
        print("Train end")

    def on_epoch_begin(self, epoch, logs=None):
        print("\tEpoch begin")

    def on_epoch_end(self, epoch, logs=None):
        print("\tEpoch end")

    # def on_train_batch_begin(self, batch, logs=None):
    #     print("\t\tBatch begin")
    #
    # def on_train_batch_end(self, batch, logs=None):
    #     print("\t\tBatch end")

# %%
from tensorflow.keras.callbacks import TensorBoard

tensorboard = TensorBoard(
    log_dir="./logs",
    histogram_freq=1,
    write_graph=True,
    write_images=True,
)

# %%
history = model.fit(x_train, y_train, epochs=20, batch_size=60, callbacks=[tensorboard] )
history = history.history
# Out:
# Epoch 1/20
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9729 - loss: 0.0945
# Epoch 2/20
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9728 - loss: 0.0952
# Epoch 3/20
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9717 - loss: 0.0972
# Epoch 4/20
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9725 - loss: 0.0968
# Epoch 5/20
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9732 - loss: 0.0944
# Epoch 6/20
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9726 - loss: 0.0963
# Epoch 7/20
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9730 - loss: 0.0941
# Epoch 8/20
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9737 - loss: 0.0925
# Epoch 9/20
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9726 - loss: 0.0955
# Epoch 10/20
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9722 - loss: 0.0960
# Epoch 11/20
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9723 - loss: 0.0949
# Epoch 12/20
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9726 - loss: 0.0930
# Epoch 13/20
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9732 - loss: 0.0951
# Epoch 14/20
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9743 - loss: 0.0899
# Epoch 15/20
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9733 - loss: 0.0911
# Epoch 16/20
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9744 - loss: 0.0892
# Epoch 17/20
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9730 - loss: 0.0943
# Epoch 18/20
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9738 - loss: 0.0914
# Epoch 19/20
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9748 - loss: 0.0884
# Epoch 20/20
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9744 - loss: 0.0894

# %%
# !tensorboard --logdir ./logs
# Out:
# ^C

# %%
from matplotlib import pyplot as plt

plt.figure(figsize=(10,5))
plt.subplot(121)
plt.plot(history["loss"],"r", label="train_loss")

plt.subplot(122)
plt.plot(history["accuracy"],"g", label="train_accuracy")

# plt.plot(model.loss_curve_, "r", label="Loss")

# %%
from sklearn.metrics import classification_report

y_pred = model.predict(x_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97       980
#            1       0.99      0.98      0.99      1135
#            2       0.97      0.95      0.96      1032
#            3       0.94      0.94      0.94      1010
#            4       0.96      0.95      0.96       982
#            5       0.93      0.94      0.94       892
#            6       0.97      0.97      0.97       958
#            7       0.94      0.97      0.96      1028
#            8       0.96      0.93      0.94       974
#            9       0.94      0.94      0.94      1009
#
#     accuracy                           0.96     10000
#    macro avg       0.96      0.96      0.96     10000
# weighted avg       0.96      0.96      0.96     10000
